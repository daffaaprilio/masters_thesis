# %% [markdown]
# # TAA key genes identification

# %%
import pandas as pd

# %%
df_sbc4 = pd.read_csv("/Users/daffa/workspace/infobio/thesis/analysis/data/tsv/SBC4.private.annotated.tsv", sep="\t")
df_sbc10 = pd.read_csv("/Users/daffa/workspace/infobio/thesis/analysis/data/tsv/SBC10.private.annotated.tsv", sep="\t")

# %%
df_sbc4
# Out:
#          chrom       pos    ref alt       qual GT_SBC4 allele  \
# 0            1       487     AG   A  52.849998     1/1      A
# 1            1       487     AG   A  52.849998     1/1      A
# 2            1       997  ATACC   A  64.190002     1/1      A
# 3            1       997  ATACC   A  64.190002     1/1      A
# 4            1      2814      G  GT  28.549999     1/1     GT
# ...        ...       ...    ...  ..        ...     ...    ...
# 2878159     10  61222478      C   T  32.939999     1/1      T
# 2878160     10  61222478      C   T  32.939999     1/1      T
# 2878161     10  61222651      C   T  29.969999     1/1      T
# 2878162     10  61222651      C   T  29.969999     1/1      T
# 2878163     10  61222651      C   T  29.969999     1/1      T
#
#                           effect    impact                    gene_name  ...  \
# 0          upstream_gene_variant  MODIFIER            SORBI_3001G000100  ...
# ...

# %%
len(df_sbc4[df_sbc4["impact"] == "HIGH"])
# Out:
# 3814

# %%
df_sbc10
# Out:
#         chrom       pos  ref     alt       qual GT_SBC10 allele  \
# 0           1      1619    G       A  54.540001      1|0      A
# 1           1      1619    G       A  54.540001      1|0      A
# 2           1      5784    A  AGG,AG  25.700001      1/2     AG
# 3           1      5784    A  AGG,AG  25.700001      1/2    AGG
# 4           1      5784    A  AGG,AG  25.700001      1/2     AG
# ...       ...       ...  ...     ...        ...      ...    ...
# 899795     10  61233582  GTT       G  35.779999      1/1      G
# 899796     10  61233615    A       T  29.270000      1/1      T
# 899797     10  61233619    T       G  27.490000      1/1      G
# 899798     10  61233644    A      AG  35.650002      1/1     AG
# 899799     10  61233676    G      GT  32.020000      1/1     GT
#
#                          effect    impact  \
# 0         upstream_gene_variant  MODIFIER
# 1             intergenic_region  MODIFIER
# 2       downstream_gene_variant  MODIFIER
# ...

# %%
len(df_sbc10[df_sbc10["impact"] == "HIGH"])
# Out:
# 1606
