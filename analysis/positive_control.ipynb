# %%
import pandas as pd
import cyvcf2

# %%
# %%bash
# VCF_PATH=../results/sift4g/merged.sift4g.vcf.gz
# ../docker/run.sh python3 ../workflow/scripts/genomics_scoring.py -i $VCF_PATH -o ../analysis/gene_score/ -g ../resources/annot/GCF_000003195.3_Sorghum_bicolor_NCBIv3_genomic.gff.gz
# Out:
# [genomics_scoring] Parsing VCF: ../results/sift4g/merged.sift4g.vcf.gz
# [genomics_scoring]   8,487,802 (variant, gene) rows
# [genomics_scoring] Written → ../analysis/gene_score/merged.variant.tsv  (8,487,802 variant annotations)
# [genomics_scoring] Loading gene lengths: ../resources/annot/GCF_000003195.3_Sorghum_bicolor_NCBIv3_genomic.gff.gz
# [genomics_scoring]   32,458 genes with length
# [genomics_scoring] Written → ../analysis/gene_score/merged.gene_max.tsv  (60,909 genes)
# [genomics_scoring] Written → ../analysis/gene_score/merged.gene_sum.tsv  (60,909 genes)
# [genomics_scoring] Written → ../analysis/gene_score/merged.gene_max_norm.tsv  (60,909 genes)
# [genomics_scoring] Written → ../analysis/gene_score/merged.gene_sum_norm.tsv  (60,909 genes)
# [genomics_scoring] Written → ../analysis/gene_score/merged.scores_summary.png
# [genomics_scoring] Written → ../analysis/gene_score/merged.variant_scores.png

# %%
df_scored               = pd.read_csv("../analysis/gene_score/merged.variant.tsv", sep="\t")
df_scored
# Out:
# /tmp/ipykernel_3721533/617784241.py:1: DtypeWarning: Columns (14,15,17,18,19,20,22,23,24,25,27,28,29,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_scored               = pd.read_csv("../analysis/gene_score/merged.variant.tsv", sep="\t")
#                chrom       pos     ref alt        qual  filter     gt  \
# 0        NC_012870.2       275       C   T   38.180000     NaN  -1/-1
# 1        NC_012870.2       275       C   T   38.180000     NaN  -1/-1
# 2        NC_012870.2       438       T   C  110.000000     NaN    1/1
# 3        NC_012870.2       438       T   C  110.000000     NaN    1/1
# 4        NC_012870.2       465  GAAGCT   G   48.810001     NaN    1/1
# ...              ...       ...     ...  ..         ...     ...    ...
# 8487797  NC_012879.2  61233646       C   G   33.669998     NaN  -1/-1
# 8487798  NC_012879.2  61233647       T   G   33.240002     NaN  -1/-1
# ...
